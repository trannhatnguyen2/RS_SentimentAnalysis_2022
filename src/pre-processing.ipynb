# %% [markdown]
# ---------------------
# # ***Importing libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import advertools as adv
import emoji
import regex as re

# %% [markdown]
# -----------------------
# # ***Loading the data set***
# - Read data

# %%
# Read data
dataset = pd.read_csv('review_shopee_after_EDA.csv')
dataset
# Out:
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# 344358     Hang Nguyen Thi                                          Rất thích
# 344359       Hoan dang van                          liệu có ổn như lazada ko?
# 344360             Tiến Đỗ  Phí vận chuyển cao. Nhân viên phục vụ lề mề ta...
# 344361              phi ha     Có lẽ từ ad bán đồ giả trong này m ng cẩn thận
# 344362          reuong van          Trang cá nhân có thành tích xuất sắc nhất
#
# ...

# %%
dataset['content_handle'] = dataset['content']
dataset
# Out:
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# 344358     Hang Nguyen Thi                                          Rất thích
# 344359       Hoan dang van                          liệu có ổn như lazada ko?
# 344360             Tiến Đỗ  Phí vận chuyển cao. Nhân viên phục vụ lề mề ta...
# 344361              phi ha     Có lẽ từ ad bán đồ giả trong này m ng cẩn thận
# 344362          reuong van          Trang cá nhân có thành tích xuất sắc nhất
#
# ...

# %% [markdown]
# ------------------------------------
# ## ***Basic data exploration***
# - Head of the dataset
# - The shape of the dataset
# - Info of the dataset

# %%
# Head of the dataset
dataset.head()
# Out:
#              userName                                            content  \
# 0  Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1            May Tran                                                 Cc
# 2           Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3            Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4          Lợi Lê thị                                  Uy tín chất lượng
#
#                  at  score  thumbsUpCount address  \
# 0  12/01/2021 23:57      4              0  Shopee
# 1  12/01/2021 23:55      1              0  Shopee
# 2  12/01/2021 23:34      2              0  Shopee
# 3  12/01/2021 23:31      5             10  Shopee
# 4  12/01/2021 23:28      5              0  Shopee
#
#                                       content_handle
# 0  Mình thấy phí ship càng ngày càng tăng không n...
# 1                                                 Cc
# 2  trời đang học online mà cũng quảng cáo shoppe ...
# ...

# %%
# The shape of the dataset
dataset.shape
# Out:
# (344363, 7)

# %%
# Info of the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344363 entries, 0 to 344362
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   userName        344363 non-null  object
#  1   content         344363 non-null  object
#  2   at              344363 non-null  object
#  3   score           344363 non-null  int64
#  4   thumbsUpCount   344363 non-null  int64
#  5   address         344363 non-null  object
#  6   content_handle  344363 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 18.4+ MB

# %% [markdown]
# __________________________
# ## ***Handling missing value***
# - Check for missing value in any column
# - Replace missing value to 'hay'

# %%
# Check for missing value in any column
dataset.isnull().sum()
# Out:
# userName          0
# content           0
# at                0
# score             0
# thumbsUpCount     0
# address           0
# content_handle    0
# dtype: int64

# %%
# Replace missing value to 'hay'
dataset.fillna('hay', inplace=True)
# Check for missing value in any column again
dataset.isnull().sum()
# Out:
# userName          0
# content           0
# at                0
# score             0
# thumbsUpCount     0
# address           0
# content_handle    0
# dtype: int64

# %% [markdown]
# ____________________
# ## ***Handling duplicate records***
# - Check for duplicate data
# - Write the code to drop the duplicate
# - Check for duplicate data again

# %%
# Check for duplicate data
duplicate = dataset.duplicated()
dataset[duplicate]
# Out:
#                 userName content                at  score  thumbsUpCount  \
# 40867  Người dùng Google      ok  19/03/2019 15:33      5              0
# 43618  Người dùng Google    good  11/02/2019 13:11      5              0
#
#       address content_handle
# 40867    Tiki             ok
# 43618    Tiki           good

# %%
# Write the code to drop the duplicate
dataset.drop_duplicates(inplace=True)

# %%
# Check for duplicate data again
dp1 = dataset.duplicated()
dp1.sum()
# Out:
# 0

# %%
# Check for missing value in any column
dataset.isnull().sum()
# Out:
# Unnamed: 0        0
# userName          0
# content           0
# at                0
# score             0
# thumbsUpCount     0
# address           0
# content_handle    0
# dtype: int64

# %%
dataset.fillna('hay', inplace=True)

# %% [markdown]
# ____________________
# ## ***Handling dataset***
# - Convert review to lowercase - (Chuyển về chữ thường)
# - Standardize Vietnamese - (Chuẩn hóa dấu Tiếng Việt)
# - Remove words over length (7) - (Xóa từ có độ dài lớn hơn 7)
# - Standard stretched words - (Chuẩn hóa từ kéo dài)
# - Remove white space, \n, \t, \r, \v - (Xóa khoảng trắng, \n, \t, \r, \v)
# - Handle teencode - (Xử lí các từ teencode)
# - Translate emoji - (Dịch emoji thành chữ)

# %%
# Convert review to lowercase
dataset['content_handle'] = dataset['content_handle'].str.lower()

# %%
emoji_dict = dict(pd.read_excel("emoji_dict.xlsx").values)
emoji_dict
# Out:
# {'😀': 'mặt cười toe toét',
#  '😃': 'khuôn mặt cười toe toét với đôi mắt to',
#  '😄': 'tàn mặt cười toe toét với đôi mắt mỉm cười',
#  '😁': 'rạng rỡ mặt với đôi mắt cười',
#  '😆': 'mặt cười toe toét',
#  '😅': 'cười toe toét với mồ hôi',
#  '🤣': 'cười lăn lộn',
#  '😂': 'đối mặt với những giọt nước mắt của niềm vui',
#  '🙂': 'mặt cười một chút',
#  '🙃': 'mặt lộn ngược',
#  '😉': 'khớp mắt',
#  '😊': 'mặt cười với đôi mắt mỉm cười',
#  '😇': 'mặt cười với hào quang',
#  '🥰': 'mặt cười với trái tim',
#  '😍': 'mặt cười với đôi mắt tim',
#  '🤩': 'mặt hào hứng',
#  '😘': 'mặt thổi một nụ hôn',
#  '😗': 'hôn mặt',
#  '☺️': 'khuôn mặt tươi cười',
#  '☺': 'khuôn mặt tươi cười',
#  '😚': 'hôn mặt với đôi mắt nhắm',
#  '😙': 'hôn mặt với đôi mắt mỉm cười',
#  '🥲': 'mỉm cười với nước mắt',
#  '😋': 'mặt thưởng thức thức ăn',
#  '😛': 'khuôn mặt với lưỡi.',
#  '😜': 'khớp mắt với lưỡi',
#  '🤪': 'khuôn mặt với lưỡi.',
#  '😝': 'khuôn mặt nheo mắt với lưỡi',
#  '🤑': 'mặt tiền miệng',
#  '🤗': 'ôm mặt',
# ...

# %%
# Function to remove emoji in text
def remove_emoji(string):
  list_emoji = adv.extract_emoji(string)['emoji_flat']
  if(len(list_emoji) > 0):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)
  return string

# %%
# Function to translate emoji
def translate_emoji(dataset, col_name, emoji_dict):

  content_handle = dataset[col_name]

  for i in range(len(content_handle)):

    result = content_handle[i]

    if(len(result) != 0):
      temp = result.strip().split(' ')
      if(len(temp) > 0):
        result_emoji = adv.extract_emoji(result)['emoji_flat']
        #result = remove_emoji(dataset[col_name][i]) + " "

        if(len(result_emoji) > 0):
          result = remove_emoji(result) + " "

          for j in result_emoji:
            if emoji_dict.__contains__(j):
              result += emoji_dict[j] + " "

        content_handle[i] = result.strip()
  
  dataset['content_handle'] = content_handle

# Handling
translate_emoji(dataset,'content_handle',emoji_dict)
dataset
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/3673804922.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content_handle[i] = result.strip()
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# 344358     Hang Nguyen Thi                                          Rất thích
# ...

# %%
# Read file teencode
teencode_dict = dict(pd.read_csv('teencode.txt', delimiter = '\t').values)

# Function to handle teencode
def handle_teencode(dataset,col_name,teencode_dict):    
    return [' '.join([teencode_dict[word] if teencode_dict.__contains__(word) else word for word in item.__str__().split(' ')]) for item in dataset[col_name]]

# Handling
dataset['content_handle'] = handle_teencode(dataset,'content_handle',teencode_dict)
dataset
# Out:
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# 344358     Hang Nguyen Thi                                          Rất thích
# 344359       Hoan dang van                          liệu có ổn như lazada ko?
# 344360             Tiến Đỗ  Phí vận chuyển cao. Nhân viên phục vụ lề mề ta...
# 344361              phi ha     Có lẽ từ ad bán đồ giả trong này m ng cẩn thận
# 344362          reuong van          Trang cá nhân có thành tích xuất sắc nhất
#
# ...

# %%
# Function to standard stretched words (Chuẩn hóa từ kéo dài)
def standardize_stretched_words(dataset,col_name):
    content_handle = dataset[col_name]
    for i in range(len(content_handle)):
        content_handle[i]= re.sub(r'(\D)\1+', r'\1', content_handle[i])

    dataset[col_name] = content_handle
        
# Handling
standardize_stretched_words(dataset,'content_handle')
dataset
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/2412523567.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content_handle[i]= re.sub(r'(\D)\1+', r'\1', content_handle[i])
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# ...

# %%
# Function to remove words over length (xóa từ có dộ dài lớn hơn 7)
def remove_words_over_length(review_row, length, container) -> None:
    st_split = review_row.split(' ')
    container.append(' '.join([word for word in st_split if word.__len__() <= length]))
    return container

# Function to convert
def listToString(s): 
    str1 = " " 
    return (str1.join(s))


# Handling 
for i in range(len(dataset)):
    temp = []
    dataset['content_handle'][i] = listToString(remove_words_over_length(dataset['content_handle'][i],7,temp))

dataset
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/4244055474.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['content_handle'][i] = listToString(remove_words_over_length(dataset['content_handle'][i],7,temp))
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# ...

# %%
# Standardize Vietnamese

uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"


def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic


dicchar = loaddicchar()


def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)


"""
    Start section: Chuyển câu văn về kiểu gõ telex khi không bật Unikey
    Ví dụ: thủy = thuyr, tượng = tuwowngj
"""
bang_nguyen_am = [['a', 'à', 'á', 'ả', 'ã', 'ạ', 'a'],
                  ['ă', 'ằ', 'ắ', 'ẳ', 'ẵ', 'ặ', 'aw'],
                  ['â', 'ầ', 'ấ', 'ẩ', 'ẫ', 'ậ', 'aa'],
                  ['e', 'è', 'é', 'ẻ', 'ẽ', 'ẹ', 'e'],
                  ['ê', 'ề', 'ế', 'ể', 'ễ', 'ệ', 'ee'],
                  ['i', 'ì', 'í', 'ỉ', 'ĩ', 'ị', 'i'],
                  ['o', 'ò', 'ó', 'ỏ', 'õ', 'ọ', 'o'],
                  ['ô', 'ồ', 'ố', 'ổ', 'ỗ', 'ộ', 'oo'],
                  ['ơ', 'ờ', 'ớ', 'ở', 'ỡ', 'ợ', 'ow'],
                  ['u', 'ù', 'ú', 'ủ', 'ũ', 'ụ', 'u'],
                  ['ư', 'ừ', 'ứ', 'ử', 'ữ', 'ự', 'uw'],
                  ['y', 'ỳ', 'ý', 'ỷ', 'ỹ', 'ỵ', 'y']]
bang_ky_tu_dau = ['', 'f', 's', 'r', 'x', 'j']

nguyen_am_to_ids = {}

for i in range(len(bang_nguyen_am)):
    for j in range(len(bang_nguyen_am[i]) - 1):
        nguyen_am_to_ids[bang_nguyen_am[i][j]] = (i, j)


def vn_word_to_telex_type(word):
    dau_cau = 0
    new_word = ''
    for char in word:
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            new_word += char
            continue
        if y != 0:
            dau_cau = y
        new_word += bang_nguyen_am[x][-1]
    new_word += bang_ky_tu_dau[dau_cau]
    return new_word


def vn_sentence_to_telex_type(sentence):
    """
    Chuyển câu tiếng việt có dấu về kiểu gõ telex.
    :param sentence:
    :return:
    """
    words = sentence.split()
    for index, word in enumerate(words):
        words[index] = vn_word_to_telex_type(word)
    return ' '.join(words)


"""
    End section: Chuyển câu văn về kiểu gõ telex khi không bật Unikey
"""

"""
    Start section: Chuyển câu văn về cách gõ dấu kiểu cũ: dùng òa úy thay oà uý
    Xem tại đây: https://vi.wikipedia.org/wiki/Quy_t%E1%BA%AFc_%C4%91%E1%BA%B7t_d%E1%BA%A5u_thanh_trong_ch%E1%BB%AF_qu%E1%BB%91c_ng%E1%BB%AF
"""


def chuan_hoa_dau_tu_tieng_viet(word):
    if not is_valid_vietnam_word(word):
        return word

    chars = list(word)
    dau_cau = 0
    nguyen_am_index = []
    qu_or_gi = False
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            continue
        elif x == 9:  # check qu
            if index != 0 and chars[index - 1] == 'q':
                chars[index] = 'u'
                qu_or_gi = True
        elif x == 5:  # check gi
            if index != 0 and chars[index - 1] == 'g':
                chars[index] = 'i'
                qu_or_gi = True
        if y != 0:
            dau_cau = y
            chars[index] = bang_nguyen_am[x][0]
        if not qu_or_gi or index != 1:
            nguyen_am_index.append(index)
    if len(nguyen_am_index) < 2:
        if qu_or_gi:
            if len(chars) == 2:
                x, y = nguyen_am_to_ids.get(chars[1])
                chars[1] = bang_nguyen_am[x][dau_cau]
            else:
                x, y = nguyen_am_to_ids.get(chars[2], (-1, -1))
                if x != -1:
                    chars[2] = bang_nguyen_am[x][dau_cau]
                else:
                    chars[1] = bang_nguyen_am[5][dau_cau] if chars[1] == 'i' else bang_nguyen_am[9][dau_cau]
            return ''.join(chars)
        return word

    for index in nguyen_am_index:
        x, y = nguyen_am_to_ids[chars[index]]
        if x == 4 or x == 8:  # ê, ơ
            chars[index] = bang_nguyen_am[x][dau_cau]
            # for index2 in nguyen_am_index:
            #     if index2 != index:
            #         x, y = nguyen_am_to_ids[chars[index]]
            #         chars[index2] = bang_nguyen_am[x][0]
            return ''.join(chars)

    if len(nguyen_am_index) == 2:
        if nguyen_am_index[-1] == len(chars) - 1:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            chars[nguyen_am_index[0]] = bang_nguyen_am[x][dau_cau]
            # x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            # chars[nguyen_am_index[1]] = bang_nguyen_am[x][0]
        else:
            # x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            # chars[nguyen_am_index[0]] = bang_nguyen_am[x][0]
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    else:
        # x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
        # chars[nguyen_am_index[0]] = bang_nguyen_am[x][0]
        x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
        chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
        # x, y = nguyen_am_to_ids[chars[nguyen_am_index[2]]]
        # chars[nguyen_am_index[2]] = bang_nguyen_am[x][0]
    return ''.join(chars)


def is_valid_vietnam_word(word):
    chars = list(word)
    nguyen_am_index = -1
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x != -1:
            if nguyen_am_index == -1:
                nguyen_am_index = index
            else:
                if index - nguyen_am_index != 1:
                    return False
                nguyen_am_index = index
    return True


def chuan_hoa_dau_cau_tieng_viet(sentence):
    """
        Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
        :param sentence:
        :return:
        """
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        # print(cw)
        if len(cw) == 3:
            cw[1] = chuan_hoa_dau_tu_tieng_viet(cw[1])
        words[index] = ''.join(cw)
    return ' '.join(words)

# %%
# Function to standardize_vietnamese
def standardize_vietnamese(dataset, col_name):
    content_handle = dataset[col_name]

    for i in range(len(content_handle)):
        content_handle[i]= chuan_hoa_dau_cau_tieng_viet(content_handle[i])

    return dataset

# Handling
standardize_vietnamese(dataset,'content_handle')
dataset
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/156876679.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content_handle[i]= chuan_hoa_dau_cau_tieng_viet(content_handle[i])
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# ...

# %%
# Function to remove white space, \n, \t, \r, \v
def remove_whitespace(dataset,col_name):
    for i in range(len(dataset)):
        dataset[col_name][i] = re.sub(r'\s+', ' ', dataset[col_name][i].strip())

# Handling
remove_whitespace(dataset,'content_handle')
dataset
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/545188342.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[col_name][i] = re.sub(r'\s+', ' ', dataset[col_name][i].strip())
#                   userName                                            content  \
# 0       Phuong Nguyen xuan  Mình thấy phí ship càng ngày càng tăng không n...
# 1                 May Tran                                                 Cc
# 2                Hùng Phạm  trời đang học online mà cũng quảng cáo shoppe ...
# 3                 Thư Ngọc                           shopee siêu xịn luôn ạ!!
# 4               Lợi Lê thị                                  Uy tín chất lượng
# ...                    ...                                                ...
# ...

# %%
# Function to remove numbers and special characters
def remove_numbers_and_special_characters(dataset,col_name):
    pattern = r'[' + string.punctuation + ']'
    for i in range(len(dataset)):
        dataset[col_name][i] = re.sub(pattern,'',dataset[col_name][i])
        dataset[col_name][i] = re.sub(r'\d+','',dataset[col_name][i])

# Handling
remove_numbers_and_special_characters(dataset,'content_handle')
dataset
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/1535265958.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[col_name][i] = re.sub(pattern,'',dataset[col_name][i])
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_1640/1535265958.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[col_name][i] = re.sub(r'\d+','',dataset[col_name][i])

# %%
dataset.to_csv('review_shopee_after_preprocessing.csv', index=False)
